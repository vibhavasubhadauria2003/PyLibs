# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading an CSV file

# %%
data=pd.read_csv('matches.csv')

# %% [markdown]
# ### Viewing Data

# %%
data.head(6)  #first n numbers
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.tail(3)  #Last n numbers
# Out:
#       id  season       city        date                team1  \
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2            toss_winner toss_decision  result  \
# 633        Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# 634          Sunrisers Hyderabad    Sunrisers Hyderabad         field  normal
# 635  Royal Challengers Bangalore    Sunrisers Hyderabad           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 633           0  Sunrisers Hyderabad           22               0
# 634           0  Sunrisers Hyderabad            0               4
# 635           0  Sunrisers Hyderabad            8               0
#
#     player_of_match                  venue          umpire1        umpire2  \
# ...

# %% [markdown]
# ## Rows and Columns of dataset

# %%
data.shape #returns a tuple which have number of rows and columns
# Out:
# (636, 18)

# %% [markdown]
# ## Data Info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %% [markdown]
# ### Describe()

# %%
data.describe()  #works only on numeric functions
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %% [markdown]
# ### Select one column

# %%
data["winner"]
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %% [markdown]
# ### Select Multiple Columns

# %%
data[['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %% [markdown]
# ### Select One Row

# %%
data.iloc[635]
# Out:
# id                                         636
# season                                    2016
# city                                 Bangalore
# date                                2016-05-29
# team1                      Sunrisers Hyderabad
# team2              Royal Challengers Bangalore
# toss_winner                Sunrisers Hyderabad
# toss_decision                              bat
# result                                  normal
# dl_applied                                   0
# winner                     Sunrisers Hyderabad
# win_by_runs                                  8
# win_by_wickets                               0
# player_of_match                    BCJ Cutting
# venue                    M Chinnaswamy Stadium
# umpire1                        HDPK Dharmasena
# umpire2                           BNJ Oxenford
# umpire3                                    NaN
# Name: 635, dtype: object

# %% [markdown]
# ### Select Multi Row

# %%
data.iloc[1:7]
#data.iloc[[1,2,3,4,5,6]]
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 2   Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 3         Kings XI Punjab              Kings XI Punjab         field  normal
# 4        Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# ...

# %%
data.iloc[:4,[4,5,10]]
# Out:
#                     team1                        team2                  winner
# 0     Sunrisers Hyderabad  Royal Challengers Bangalore     Sunrisers Hyderabad
# 1          Mumbai Indians       Rising Pune Supergiant  Rising Pune Supergiant
# 2           Gujarat Lions        Kolkata Knight Riders   Kolkata Knight Riders
# 3  Rising Pune Supergiant              Kings XI Punjab         Kings XI Punjab

# %% [markdown]
# #### Other way

# %%
data[["team1","team2","winner"]].iloc[:4]
# Out:
#                     team1                        team2                  winner
# 0     Sunrisers Hyderabad  Royal Challengers Bangalore     Sunrisers Hyderabad
# 1          Mumbai Indians       Rising Pune Supergiant  Rising Pune Supergiant
# 2           Gujarat Lions        Kolkata Knight Riders   Kolkata Knight Riders
# 3  Rising Pune Supergiant              Kings XI Punjab         Kings XI Punjab

# %% [markdown]
# ### Count Function

# %%
data.iloc[:,[10]].value_counts()
# Out:
# winner
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: count, dtype: int64

# %% [markdown]
# ### Bargraph

# %%
data.iloc[:,[10]].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %% [markdown]
# ### Pichart

# %%
data.iloc[:,[7]].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Histogram

# %%
data.iloc[:,[11]].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Sorting in DataFrame
# ### By Single column

# %%
data.sort_values('date',ascending=False)
#to make data permanent
#data.sort_values('city',ascending=False,inplace=True)
# Out:
#     id  season        city        date                        team1  \
# 58  59    2017   Hyderabad  2017-05-21               Mumbai Indians
# 57  58    2017   Bangalore  2017-05-19        Kolkata Knight Riders
# 56  57    2017   Bangalore  2017-05-17          Sunrisers Hyderabad
# 55  56    2017      Mumbai  2017-05-16       Rising Pune Supergiant
# 54  55    2017       Delhi  2017-05-14  Royal Challengers Bangalore
# ..  ..     ...         ...         ...                          ...
# 62  63    2008      Mumbai  2008-04-20               Mumbai Indians
# 63  64    2008     Kolkata  2008-04-20              Deccan Chargers
# 61  62    2008       Delhi  2008-04-19             Rajasthan Royals
# 60  61    2008  Chandigarh  2008-04-19          Chennai Super Kings
# 59  60    2008   Bangalore  2008-04-18        Kolkata Knight Riders
#
#                           team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# ### By multi-columns

# %%
data.sort_values(['season','city'],ascending=[False,False])
# Out:
#       id  season       city        date                        team1  \
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 12    13    2017     Rajkot  2017-04-14       Rising Pune Supergiant
# 19    20    2017     Rajkot  2017-04-18  Royal Challengers Bangalore
# 25    26    2017     Rajkot  2017-04-23              Kings XI Punjab
# 33    34    2017     Rajkot  2017-04-29                Gujarat Lions
# ..   ...     ...        ...         ...                          ...
# 73    74    2008  Bangalore  2008-04-28          Chennai Super Kings
# 83    84    2008  Bangalore  2008-05-05  Royal Challengers Bangalore
# 89    90    2008  Bangalore  2008-05-28  Royal Challengers Bangalore
# 103  104    2008  Bangalore  2008-05-19  Royal Challengers Bangalore
# 110  111    2008  Bangalore  2008-05-03  Royal Challengers Bangalore
#
#                            team2            toss_winner toss_decision  result  \
# ...

# %% [markdown]
# ### Delete Duplicates

# %%
data.drop_duplicates(subset=['toss_decision','city'])
# Out:
#       id  season            city        date                        team1  \
# 0      1    2017       Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017            Pune  2017-04-06               Mumbai Indians
# 2      3    2017          Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017          Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017       Bangalore  2017-04-08  Royal Challengers Bangalore
# 6      7    2017          Mumbai  2017-04-09        Kolkata Knight Riders
# 7      8    2017          Indore  2017-04-10  Royal Challengers Bangalore
# 10    11    2017         Kolkata  2017-04-13              Kings XI Punjab
# 11    12    2017       Bangalore  2017-04-14  Royal Challengers Bangalore
# 14    15    2017           Delhi  2017-04-15             Delhi Daredevils
# 20    21    2017       Hyderabad  2017-04-19          Sunrisers Hyderabad
# 31    32    2017      Chandigarh  2017-04-28          Sunrisers Hyderabad
# ...

# %% [markdown]
# ### Q-Print the winer of each season

# %%
x=data.sort_values(['season'],ascending=[True]) #sorting data where season is ascending but date is desending
y=x.drop_duplicates(subset=['season']) #delecting rest of data other than first
y.iloc[:,[1,10]]
# Out:
#      season                 winner
# 63     2008  Kolkata Knight Riders
# 122    2009  Kolkata Knight Riders
# 200    2010         Mumbai Indians
# 240    2011       Rajasthan Royals
# 376    2012         Mumbai Indians
# 449    2013        Kings XI Punjab
# 463    2014        Kings XI Punjab
# 526    2015  Kolkata Knight Riders
# 616    2016         Mumbai Indians
# 36     2017         Mumbai Indians
